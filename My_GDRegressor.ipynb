# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,Y=make_regression(n_samples=100,n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
from sklearn.model_selection import train_test_split
xTrain,xTest,yTrain,yTest=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xTrain,yTrain)
y_pred=lr.predict(xTest)

# %%
from sklearn.metrics import r2_score
print("R2:",r2_score(yTest,y_pred))
# Out:
# R2: 0.6186926408914155

# %%
lr.coef_
# Out:
# array([28.16404017])

# %%
lr.intercept_
# Out:
# np.float64(-2.7130725669241036)

# %%
m=lr.coef_[0]
m
# Out:
# np.float64(28.16404017122941)

# %% [markdown]
# # **For finding b-intercept**

# %%
class GDRegressor():
  def __init__(self,learning_rate,epochs):
    self.b=0
    self.m=28.164
    self.lr=learning_rate
    self.epochs=epochs
  
  def fit(self,xTrain,yTrain):
    for i in range(self.epochs):
      loss_func=-2*np.sum(yTrain-self.m*xTrain.ravel()-self.b)
      self.b=self.b-(self.lr*loss_func)
    print(self.b)

# %%
gdr=GDRegressor(0.1,10)
gdr.fit(xTrain,yTrain)
# Out:
# 1564493790867.8276

# %% [markdown]
# There is a very high diffrence between expected answer and what we actually got this is because our learnng rate is way too high:

# %%
gdr=GDRegressor(0.01,10)
gdr.fit(xTrain,yTrain)
# Out:
# -2.6966666813390243

# %% [markdown]
# Now as we can see it is closer to the expexted b intercept (-2.71) but still not equal now we increase the epochs:

# %%
gdr=GDRegressor(0.01,100)
gdr.fit(xTrain,yTrain)
# Out:
# -2.7130715877515823

# %% [markdown]
# Finally we have the expected answer
#
# ---

# %% [markdown]
# # Now lets do for both slope and b intercept

# %%
class GDRegressor():
  def __init__(self,epoch,learning_rate):
    self.epoch=epoch
    self.lr=learning_rate
    self.m=100
    self.b=-120

  def fit(self,xTrain,yTrain):
    for i in range(self.epoch):
      slope_b=-2*np.sum(yTrain-self.m*xTrain.ravel()-self.b)
      slope_m = -2*np.sum((yTrain-self.m*xTrain.ravel()-self.b)*xTrain.ravel())

      self.b=self.b-(self.lr*slope_b)
      self.m=self.m-(self.lr*slope_m)

  def predict(self,xTest):
    return self.m * xTest + self.b

# %%
gd=GDRegressor(20,0.01)
gd.fit(xTrain,yTrain)

# %%
y_pred=gd.predict(xTest)

# %%
print("r2 score: ", r2_score(yTest,y_pred))
# Out:
# r2 score:  0.6186743714823241
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
# ...
