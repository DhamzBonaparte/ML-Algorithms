# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('./play_tennis.csv')

# %%
df['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
yp=9/14
yn=5/14
pd.crosstab(df['outlook'],df['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
nover=0
nrain=2/5
nsunny=3/5

yover=4/9
yrain=3/9
ysunny=2/9
pd.crosstab(df['temp'],df['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
ncool=1/5
nhot=2/5
nmild=2/5

ycool=3/9
yhot=2/9
ymild=4/9
pd.crosstab(df['humidity'],df['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
yhigh=3/9
ynormal=6/9

nhigh=4/5
nnormal=1/5
pd.crosstab(df['wind'],df['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
nstrong=3/5
nweak=2/5

ystrong=3/9
yweak=6/9

# %%
# for sunny,mild,weak
ypred=yp*ysunny*ymild*yweak
print(ypred)
# Out:
# 0.042328042328042326

# %%
npred=yn*nsunny*nmild*nweak
print(npred)
# Out:
# 0.03428571428571429

# %% [markdown]
# ### As we can see the prediction of Yes play (ypred) is more than No play (npred) so the match will be played
